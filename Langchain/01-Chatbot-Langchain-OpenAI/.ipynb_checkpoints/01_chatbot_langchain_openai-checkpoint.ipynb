# %% [markdown]
# # **Simple Chatbot** using LangChain and OpenAI

# %%
# Install the necessary packages
# !pip install langchain -qU
# !pip install langchain-openai -qU
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install python-dotenv
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-dotenv in c:\users\gshpe\appdata\local\programs\python\python312\lib\site-packages (1.2.1)

# %%
# Import necessary libraries
import os
from dotenv import load_dotenv

load_dotenv()
# from google.colab import userdata
# Out:
# False

# %% [markdown]
# ### Initialize OpenAI LLM

# %%
from langchain_openai import ChatOpenAI

# Set OpenAI API key
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# Initialize the ChatOpenAI model
llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature=0
)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[5], line 8
#       4 OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
#       5 # os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')
#       6
#       7 # Initialize the ChatOpenAI model
# ----> 8 llm = ChatOpenAI(
#       9     model="gpt-3.5-turbo",
#      10     temperature=0
#      11 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\load\serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_openai\chat_models\base.py:948, in BaseChatOpenAI.validate_environment(self)
#     938         self.http_async_client = httpx.AsyncClient(
#     939             proxy=self.openai_proxy, verify=global_ssl_context
#     940         )
#     941     async_specific = {
#     942         "http_client": self.http_async_client
#     943         or _get_default_async_httpx_client(
#    (...)
#     946         "api_key": async_api_key_value,
#     947     }
# --> 948     self.root_async_client = openai.AsyncOpenAI(
#     949         **client_params,
#     950         **async_specific,  # type: ignore[arg-type]
#     951     )
#     952     self.async_client = self.root_async_client.chat.completions
#     953 return self
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %% [markdown]
# ### Initialize Prompt Template

# %%
from langchain_core.prompts import ChatPromptTemplate

# Create a prompt template
prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are an intelligent chatbot. Answer the following question."),
        ("user", "{question}")
    ]
)

# %% [markdown]
# ### Initialize Output Parser

# %%
from langchain_core.output_parsers import StrOutputParser

# Initialize the string output parser
parser = StrOutputParser()

# %%
# Chain the prompt, LLM, and output parser
chain = prompt | llm | parser

# %%
question = "My name is codeprolk"

response = chain.invoke({"question": question})

print(response)
# Out:
# Nice to meet you, codeprolk! How can I assist you today?

# %% [markdown]
# ### Initialize Prompt Template for Dynamic Interaction

# %%
from langchain_core.prompts import MessagesPlaceholder
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

# Create a prompt template using MessagesPlaceholder for the question
prompt = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content="You are an intelligent chatbot. Answer the following question."),
        MessagesPlaceholder(variable_name="question")
    ]
)

# Chain the prompt, LLM, and output parser
chain = prompt | llm | parser

# %%
question = "My name is codeprolk"

response = chain.invoke({"question": [HumanMessage(content=question)]})

print(response)
# Out:
# Nice to meet you, codeprolk! How can I assist you today?

# %%
question = "Who am I"

response = chain.invoke({"question": [HumanMessage(content=question)]})

print(response)
# Out:
# You are a user interacting with me, a chatbot, on this platform. How can I assist you today?

# %% [markdown]
# ### Initialize Prompt Template with Predefined Conversation History

# %%
# Create a prompt template with a predefined conversation history and a new question placeholder
prompt = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content="You are an intelligent chatbot. Answer the following question."),
        HumanMessage(content="My name is codeprolk"),
        AIMessage(content="Nice to meet you, codeprolk! How can I assist you today?"),
        MessagesPlaceholder(variable_name="question")
    ]
)

# Chain the prompt, LLM, and output parser
chain = prompt | llm | parser

# %%
question = "Who am I"

response = chain.invoke({"question": [HumanMessage(content=question)]})

print(response)
# Out:
# You are codeprolk, a user interacting with me right now. How can I help you further, codeprolk?

# %% [markdown]
# ### Initialize Prompt Template to Handle Dynamic Conversation History

# %%
# Create a prompt template with a dynamic conversation history and a new question placeholder
prompt = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content="You are an intelligent chatbot. Answer the following question."),
        MessagesPlaceholder(variable_name="history"),
        MessagesPlaceholder(variable_name="question")
    ]
)

# Chain the prompt, LLM, and output parser
chain = prompt | llm | parser

# %%
# Define the conversation history
history = [
    HumanMessage(content="My name is codeprolk"),
    AIMessage(content="Nice to meet you, codeprolk! How can I assist you today?"),
    HumanMessage(content="what is 2 + 2"),
    AIMessage(content="4")
]

# %%
question = "Who am I"

response = chain.invoke({"history": history, "question": [HumanMessage(content=question)]})

print(response)
# Out:
# You are codeprolk.

# %% [markdown]
# ### Update and Display Conversation History

# %%
history
# Out:
# [HumanMessage(content='My name is codeprolk'),
#  AIMessage(content='Nice to meet you, codeprolk! How can I assist you today?'),
#  HumanMessage(content='what is 2 + 2'),
#  AIMessage(content='4')]

# %%
# Extend the history with the latest question and response
history.extend([HumanMessage(content=question), AIMessage(content=response)])

# %%
history
# Out:
# [HumanMessage(content='My name is codeprolk'),
#  AIMessage(content='Nice to meet you, codeprolk! How can I assist you today?'),
#  HumanMessage(content='what is 2 + 2'),
#  AIMessage(content='4'),
#  HumanMessage(content='Who am I'),
#  AIMessage(content='You are codeprolk.')]

# %%
question = "what's my last question?"

response = chain.invoke({"history": history, "question": [HumanMessage(content=question)]})

history.extend([HumanMessage(content=question), AIMessage(content=response)])

print(response)
# Out:
# Your last question was "Who am I".

# %%
history
# Out:
# [HumanMessage(content='My name is codeprolk'),
#  AIMessage(content='Nice to meet you, codeprolk! How can I assist you today?'),
#  HumanMessage(content='what is 2 + 2'),
#  AIMessage(content='4'),
#  HumanMessage(content='Who am I'),
#  AIMessage(content='You are codeprolk.'),
#  HumanMessage(content="what's my last question?"),
#  AIMessage(content='Your last question was "Who am I".')]

# %%
# Display the last four interactions in the conversation history
history[-4:]
# Out:
# [HumanMessage(content='Who am I'),
#  AIMessage(content='You are codeprolk.'),
#  HumanMessage(content="what's my last question?"),
#  AIMessage(content='Your last question was "Who am I".')]
